# %% [markdown]
# <a href="https://colab.research.google.com/github/dkiran100/Automatic-hand-tracking/blob/main/Hand_tracking_mediapipe_ultralytics_sam2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics torch torchvision torchaudio opencv-python numpy matplotlib mediapipe
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.70-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Collecting mediapipe
#   Downloading mediapipe-0.10.20-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.1.24)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.25.6)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Downloading ultralytics-8.3.70-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 53.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 66.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 15.4 MB/s eta 0:00:00
# Downloading mediapipe-0.10.20-cp311-cp311-manylinux_2_28_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 59.9 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, sounddevice, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, mediapipe, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed mediapipe-0.10.20 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 sounddevice-0.5.1 ultralytics-8.3.70 ultralytics-thop-2.0.14

# %%
import cv2
import torch
import numpy as np
import mediapipe as mp
from ultralytics import SAM

# Load SAM 2 model
model = SAM("sam2_b.pt")

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5)
mp_draw = mp.solutions.drawing_utils

# Load video
video_path = "/content/drive/MyDrive/VLM/test.mp4"
cap = cv2.VideoCapture(video_path)

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# Define output writer
output_path = "/content/drive/MyDrive/VLM/output_video.mp4"
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

frame_number = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_number += 1
    print(f"Processing frame {frame_number}/{frame_count}...")

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results_hands = hands.process(rgb_frame)

    hand_bboxes = []
    if results_hands.multi_hand_landmarks:
        for hand_landmarks in results_hands.multi_hand_landmarks:
            x_min, y_min, x_max, y_max = width, height, 0, 0
            for landmark in hand_landmarks.landmark:
                x, y = int(landmark.x * width), int(landmark.y * height)
                x_min, y_min = min(x_min, x), min(y_min, y)
                x_max, y_max = max(x_max, x), max(y_max, y)

            x_min, y_min = max(x_min - 10, 0), max(y_min - 10, 0)
            x_max, y_max = min(x_max + 10, width), min(y_max + 10, height)
            hand_bboxes.append((x_min, y_min, x_max, y_max))

    mask = np.zeros((height, width), dtype=np.uint8)

    if hand_bboxes:
        for (x_min, y_min, x_max, y_max) in hand_bboxes:
            hand_roi = rgb_frame[y_min:y_max, x_min:x_max]
            if hand_roi.shape[0] > 0 and hand_roi.shape[1] > 0:
                results = model(hand_roi)
                if results and hasattr(results[0], "masks") and results[0].masks is not None:
                    sam_mask = results[0].masks.data.cpu().numpy()
                    if sam_mask.shape[0] > 0:
                        mask_resized = cv2.resize(
                            (sam_mask[0] * 255).astype(np.uint8),
                            (x_max - x_min, y_max - y_min),
                            interpolation=cv2.INTER_NEAREST,
                        )
                        mask[y_min:y_max, x_min:x_max] = mask_resized

    if mask.any():
        overlay = cv2.applyColorMap(mask, cv2.COLORMAP_JET)
        blended_frame = cv2.addWeighted(frame, 0.5, overlay, 0.5, 0)
    else:
        blended_frame = frame.copy()

    for (x_min, y_min, x_max, y_max) in hand_bboxes:
        cv2.rectangle(blended_frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)

    if results_hands.multi_hand_landmarks:
        for hand_landmarks in results_hands.multi_hand_landmarks:
            mp_draw.draw_landmarks(blended_frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

    out.write(blended_frame)

cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Processing complete! Output video saved at: {output_path}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/sam2_b.pt to 'sam2_b.pt'...
# 100%|██████████| 154M/154M [00:04<00:00, 38.0MB/s]
# Processing frame 1/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 5809.0ms
# Speed: 89.6ms preprocess, 5809.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1681.8ms
# Speed: 9.1ms preprocess, 1681.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 2/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1706.1ms
# Speed: 8.3ms preprocess, 1706.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1691.2ms
# Speed: 5.4ms preprocess, 1691.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 3/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1708.5ms
# Speed: 6.2ms preprocess, 1708.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1685.5ms
# Speed: 5.4ms preprocess, 1685.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 4/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1701.3ms
# Speed: 8.4ms preprocess, 1701.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1 6, 1681.1ms
# Speed: 5.6ms preprocess, 1681.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 5/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1701.6ms
# Speed: 5.9ms preprocess, 1701.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1681.3ms
# Speed: 5.3ms preprocess, 1681.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 6/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1696.7ms
# Speed: 7.2ms preprocess, 1696.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1680.2ms
# Speed: 5.4ms preprocess, 1680.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 7/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1695.1ms
# Speed: 5.9ms preprocess, 1695.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1676.3ms
# Speed: 5.3ms preprocess, 1676.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 8/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1692.3ms
# Speed: 5.6ms preprocess, 1692.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1668.6ms
# Speed: 5.5ms preprocess, 1668.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 9/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1692.2ms
# Speed: 5.9ms preprocess, 1692.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1679.1ms
# Speed: 5.5ms preprocess, 1679.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 10/210...
#
# 0: 1024x1024 1 0, 1 1, 1689.6ms
# Speed: 5.7ms preprocess, 1689.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1672.5ms
# Speed: 5.5ms preprocess, 1672.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 11/210...
#
# 0: 1024x1024 1 0, 1 1, 1687.8ms
# Speed: 5.7ms preprocess, 1687.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1673.1ms
# Speed: 5.4ms preprocess, 1673.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 12/210...
#
# 0: 1024x1024 1 0, 1 1, 1684.4ms
# Speed: 5.7ms preprocess, 1684.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1675.0ms
# Speed: 5.5ms preprocess, 1675.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 13/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1679.9ms
# Speed: 5.7ms preprocess, 1679.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1682.0ms
# Speed: 5.6ms preprocess, 1682.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 14/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1691.8ms
# Speed: 6.2ms preprocess, 1691.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1678.0ms
# Speed: 5.4ms preprocess, 1678.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 15/210...
#
# 0: 1024x1024 1 0, 1 1, 1675.9ms
# Speed: 5.8ms preprocess, 1675.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1681.7ms
# Speed: 5.9ms preprocess, 1681.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 16/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1674.4ms
# Speed: 5.6ms preprocess, 1674.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1677.8ms
# Speed: 5.4ms preprocess, 1677.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 17/210...
#
# 0: 1024x1024 1 0, 1 1, 1681.2ms
# Speed: 5.6ms preprocess, 1681.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1678.6ms
# Speed: 5.4ms preprocess, 1678.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 18/210...
#
# 0: 1024x1024 1 0, 1674.0ms
# Speed: 5.8ms preprocess, 1674.0ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1669.4ms
# Speed: 5.5ms preprocess, 1669.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 19/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1681.3ms
# Speed: 5.7ms preprocess, 1681.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1672.7ms
# Speed: 5.5ms preprocess, 1672.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 20/210...
#
# 0: 1024x1024 1 0, 1677.0ms
# Speed: 5.7ms preprocess, 1677.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1686.7ms
# Speed: 5.5ms preprocess, 1686.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 21/210...
#
# 0: 1024x1024 1 0, 1 1, 1680.2ms
# Speed: 5.7ms preprocess, 1680.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1673.9ms
# Speed: 5.7ms preprocess, 1673.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 22/210...
#
# 0: 1024x1024 1 0, 1680.3ms
# Speed: 5.6ms preprocess, 1680.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1669.2ms
# Speed: 5.7ms preprocess, 1669.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 23/210...
#
# 0: 1024x1024 1 0, 1 1, 1684.2ms
# Speed: 5.8ms preprocess, 1684.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1679.3ms
# Speed: 5.4ms preprocess, 1679.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 24/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1677.3ms
# Speed: 5.7ms preprocess, 1677.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1689.4ms
# Speed: 5.7ms preprocess, 1689.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 25/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1677.4ms
# Speed: 5.5ms preprocess, 1677.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1671.5ms
# Speed: 5.7ms preprocess, 1671.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 26/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1678.7ms
# Speed: 5.5ms preprocess, 1678.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1671.7ms
# Speed: 5.5ms preprocess, 1671.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 27/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1675.0ms
# Speed: 5.6ms preprocess, 1675.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1691.8ms
# Speed: 5.5ms preprocess, 1691.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 28/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1679.5ms
# Speed: 5.6ms preprocess, 1679.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1676.6ms
# Speed: 5.5ms preprocess, 1676.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 29/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1675.9ms
# Speed: 5.7ms preprocess, 1675.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1668.3ms
# Speed: 5.7ms preprocess, 1668.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 30/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1677.3ms
# Speed: 5.9ms preprocess, 1677.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1672.8ms
# Speed: 5.4ms preprocess, 1672.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 31/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1688.1ms
# Speed: 5.6ms preprocess, 1688.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1677.7ms
# Speed: 5.5ms preprocess, 1677.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 32/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1670.7ms
# Speed: 5.6ms preprocess, 1670.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1673.6ms
# Speed: 5.6ms preprocess, 1673.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 33/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1673.8ms
# Speed: 5.6ms preprocess, 1673.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1683.7ms
# Speed: 5.6ms preprocess, 1683.7ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 34/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1672.2ms
# Speed: 5.5ms preprocess, 1672.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1677.5ms
# Speed: 5.4ms preprocess, 1677.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 35/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1676.3ms
# Speed: 5.6ms preprocess, 1676.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1674.3ms
# Speed: 8.3ms preprocess, 1674.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 36/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1678.9ms
# Speed: 8.1ms preprocess, 1678.9ms inference, 0.9ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1675.4ms
# Speed: 5.6ms preprocess, 1675.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 37/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1687.8ms
# Speed: 5.6ms preprocess, 1687.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1673.2ms
# Speed: 5.4ms preprocess, 1673.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 38/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1677.0ms
# Speed: 5.4ms preprocess, 1677.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1688.2ms
# Speed: 5.7ms preprocess, 1688.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 39/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1678.6ms
# Speed: 6.0ms preprocess, 1678.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1679.4ms
# Speed: 5.5ms preprocess, 1679.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 40/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1678.3ms
# Speed: 5.8ms preprocess, 1678.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1682.7ms
# Speed: 5.5ms preprocess, 1682.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 41/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1688.8ms
# Speed: 5.8ms preprocess, 1688.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1680.4ms
# Speed: 5.6ms preprocess, 1680.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 42/210...
#
# 0: 1024x1024 1 0, 1 1, 1693.0ms
# Speed: 5.8ms preprocess, 1693.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1689.3ms
# Speed: 5.6ms preprocess, 1689.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 43/210...
#
# 0: 1024x1024 1 0, 1 1, 1685.7ms
# Speed: 5.8ms preprocess, 1685.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1679.3ms
# Speed: 5.4ms preprocess, 1679.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 44/210...
#
# 0: 1024x1024 1 0, 1 1, 1685.2ms
# Speed: 5.7ms preprocess, 1685.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1683.9ms
# Speed: 6.0ms preprocess, 1683.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 45/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1684.9ms
# Speed: 5.6ms preprocess, 1684.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1688.6ms
# Speed: 5.4ms preprocess, 1688.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 46/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1687.9ms
# Speed: 5.7ms preprocess, 1687.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1682.8ms
# Speed: 5.5ms preprocess, 1682.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 47/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1685.6ms
# Speed: 5.9ms preprocess, 1685.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1681.6ms
# Speed: 5.4ms preprocess, 1681.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 48/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1690.6ms
# Speed: 5.6ms preprocess, 1690.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1685.5ms
# Speed: 5.4ms preprocess, 1685.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 49/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1682.5ms
# Speed: 5.6ms preprocess, 1682.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1687.0ms
# Speed: 5.5ms preprocess, 1687.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 50/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1681.2ms
# Speed: 5.5ms preprocess, 1681.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1683.9ms
# Speed: 5.4ms preprocess, 1683.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 51/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1678.7ms
# Speed: 5.8ms preprocess, 1678.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1687.1ms
# Speed: 5.3ms preprocess, 1687.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 52/210...
#
# 0: 1024x1024 1 0, 1 1, 1670.4ms
# Speed: 5.5ms preprocess, 1670.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1681.5ms
# Speed: 5.5ms preprocess, 1681.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 53/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1683.4ms
# Speed: 5.7ms preprocess, 1683.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1680.6ms
# Speed: 5.3ms preprocess, 1680.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 54/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1678.7ms
# Speed: 5.8ms preprocess, 1678.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1684.9ms
# Speed: 5.5ms preprocess, 1684.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 55/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1681.5ms
# Speed: 5.8ms preprocess, 1681.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1669.9ms
# Speed: 5.4ms preprocess, 1669.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 56/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1684.9ms
# Speed: 5.5ms preprocess, 1684.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1677.2ms
# Speed: 5.4ms preprocess, 1677.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 57/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1677.5ms
# Speed: 5.5ms preprocess, 1677.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1681.0ms
# Speed: 5.6ms preprocess, 1681.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 58/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1686.7ms
# Speed: 5.6ms preprocess, 1686.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1675.6ms
# Speed: 6.0ms preprocess, 1675.6ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 59/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1678.8ms
# Speed: 5.7ms preprocess, 1678.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1680.1ms
# Speed: 5.6ms preprocess, 1680.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 60/210...
#
# 0: 1024x1024 1 0, 1 1, 1677.4ms
# Speed: 5.7ms preprocess, 1677.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1676.1ms
# Speed: 5.6ms preprocess, 1676.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 61/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1690.1ms
# Speed: 6.2ms preprocess, 1690.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1676.4ms
# Speed: 5.4ms preprocess, 1676.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 62/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1678.3ms
# Speed: 5.8ms preprocess, 1678.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1670.3ms
# Speed: 5.7ms preprocess, 1670.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 63/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1674.4ms
# Speed: 5.7ms preprocess, 1674.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1671.0ms
# Speed: 5.6ms preprocess, 1671.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 64/210...
#
# 0: 1024x1024 1 0, 1673.0ms
# Speed: 6.0ms preprocess, 1673.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 65/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1681.0ms
# Speed: 6.2ms preprocess, 1681.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1682.1ms
# Speed: 5.4ms preprocess, 1682.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 66/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1674.8ms
# Speed: 5.7ms preprocess, 1674.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 67/210...
#
# 0: 1024x1024 1 0, 1 1, 1669.7ms
# Speed: 6.0ms preprocess, 1669.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1675.9ms
# Speed: 5.5ms preprocess, 1675.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 68/210...
#
# 0: 1024x1024 1 0, 1 1, 1664.3ms
# Speed: 5.7ms preprocess, 1664.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 69/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1676.2ms
# Speed: 6.7ms preprocess, 1676.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1677.8ms
# Speed: 5.4ms preprocess, 1677.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 70/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1665.2ms
# Speed: 5.8ms preprocess, 1665.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 71/210...
#
# 0: 1024x1024 1 0, 1 1, 1674.4ms
# Speed: 6.1ms preprocess, 1674.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1669.2ms
# Speed: 5.6ms preprocess, 1669.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 72/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1679.5ms
# Speed: 5.6ms preprocess, 1679.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 73/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1669.1ms
# Speed: 6.2ms preprocess, 1669.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1676.5ms
# Speed: 5.8ms preprocess, 1676.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 74/210...
#
# 0: 1024x1024 1 0, 1 1, 1675.2ms
# Speed: 5.8ms preprocess, 1675.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1669.2ms
# Speed: 5.7ms preprocess, 1669.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 75/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1678.6ms
# Speed: 5.7ms preprocess, 1678.6ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1658.6ms
# Speed: 5.6ms preprocess, 1658.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 76/210...
#
# 0: 1024x1024 1 0, 1 1, 1673.7ms
# Speed: 5.6ms preprocess, 1673.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1663.1ms
# Speed: 5.7ms preprocess, 1663.1ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 77/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1682.6ms
# Speed: 5.4ms preprocess, 1682.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1679.2ms
# Speed: 5.4ms preprocess, 1679.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 78/210...
#
# 0: 1024x1024 1 0, 1668.3ms
# Speed: 5.5ms preprocess, 1668.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1686.9ms
# Speed: 5.6ms preprocess, 1686.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 79/210...
#
# 0: 1024x1024 1 0, 1 1, 1672.2ms
# Speed: 5.7ms preprocess, 1672.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1687.9ms
# Speed: 5.3ms preprocess, 1687.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 80/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1683.9ms
# Speed: 5.4ms preprocess, 1683.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1680.0ms
# Speed: 5.3ms preprocess, 1680.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 81/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1687.3ms
# Speed: 5.5ms preprocess, 1687.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1682.0ms
# Speed: 5.6ms preprocess, 1682.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 82/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1678.7ms
# Speed: 5.6ms preprocess, 1678.7ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1682.5ms
# Speed: 5.5ms preprocess, 1682.5ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 83/210...
#
# 0: 1024x1024 1 0, 1 1, 1677.0ms
# Speed: 5.3ms preprocess, 1677.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1677.8ms
# Speed: 5.6ms preprocess, 1677.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 84/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1680.3ms
# Speed: 5.4ms preprocess, 1680.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1675.0ms
# Speed: 5.4ms preprocess, 1675.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 85/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1678.1ms
# Speed: 5.5ms preprocess, 1678.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1669.1ms
# Speed: 5.7ms preprocess, 1669.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 86/210...
#
# 0: 1024x1024 1 0, 1 1, 1660.9ms
# Speed: 5.6ms preprocess, 1660.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1678.5ms
# Speed: 5.5ms preprocess, 1678.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 87/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1662.0ms
# Speed: 5.6ms preprocess, 1662.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1671.7ms
# Speed: 5.6ms preprocess, 1671.7ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 88/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1659.5ms
# Speed: 5.4ms preprocess, 1659.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1680.3ms
# Speed: 5.7ms preprocess, 1680.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 89/210...
#
# 0: 1024x1024 1 0, 1654.0ms
# Speed: 5.8ms preprocess, 1654.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1674.5ms
# Speed: 5.7ms preprocess, 1674.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 90/210...
#
# 0: 1024x1024 1 0, 1 1, 1657.3ms
# Speed: 5.3ms preprocess, 1657.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1681.8ms
# Speed: 5.8ms preprocess, 1681.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 91/210...
#
# 0: 1024x1024 1 0, 1665.7ms
# Speed: 5.5ms preprocess, 1665.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1684.4ms
# Speed: 5.7ms preprocess, 1684.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 92/210...
#
# 0: 1024x1024 1 0, 1 1, 1660.7ms
# Speed: 5.7ms preprocess, 1660.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1673.5ms
# Speed: 5.9ms preprocess, 1673.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 93/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1662.0ms
# Speed: 5.8ms preprocess, 1662.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1682.4ms
# Speed: 5.8ms preprocess, 1682.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 94/210...
#
# 0: 1024x1024 1 0, 1 1, 1654.9ms
# Speed: 5.5ms preprocess, 1654.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1664.6ms
# Speed: 5.6ms preprocess, 1664.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 95/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1661.5ms
# Speed: 5.6ms preprocess, 1661.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1663.7ms
# Speed: 5.6ms preprocess, 1663.7ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 96/210...
#
# 0: 1024x1024 1 0, 1 1, 1671.0ms
# Speed: 5.6ms preprocess, 1671.0ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1669.4ms
# Speed: 5.7ms preprocess, 1669.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 97/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1668.2ms
# Speed: 5.7ms preprocess, 1668.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1667.8ms
# Speed: 5.8ms preprocess, 1667.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 98/210...
#
# 0: 1024x1024 1 0, 1 1, 1659.0ms
# Speed: 5.8ms preprocess, 1659.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1666.5ms
# Speed: 5.8ms preprocess, 1666.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 99/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1661.2ms
# Speed: 5.7ms preprocess, 1661.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1657.3ms
# Speed: 6.3ms preprocess, 1657.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 100/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1673.3ms
# Speed: 5.8ms preprocess, 1673.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1661.4ms
# Speed: 5.9ms preprocess, 1661.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 101/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1679.9ms
# Speed: 5.7ms preprocess, 1679.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1664.6ms
# Speed: 6.1ms preprocess, 1664.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 102/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1681.0ms
# Speed: 5.7ms preprocess, 1681.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1661.1ms
# Speed: 5.7ms preprocess, 1661.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 103/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1685.0ms
# Speed: 6.0ms preprocess, 1685.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1666.3ms
# Speed: 6.1ms preprocess, 1666.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 104/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1678.7ms
# Speed: 5.6ms preprocess, 1678.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1660.7ms
# Speed: 5.7ms preprocess, 1660.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 105/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1674.3ms
# Speed: 6.1ms preprocess, 1674.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1663.3ms
# Speed: 6.0ms preprocess, 1663.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 106/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1669.1ms
# Speed: 5.7ms preprocess, 1669.1ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1661.4ms
# Speed: 5.8ms preprocess, 1661.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 107/210...
#
# 0: 1024x1024 1 0, 1 1, 1665.0ms
# Speed: 5.6ms preprocess, 1665.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1659.4ms
# Speed: 5.8ms preprocess, 1659.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 108/210...
#
# 0: 1024x1024 1 0, 1 1, 1662.1ms
# Speed: 5.8ms preprocess, 1662.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1662.9ms
# Speed: 5.6ms preprocess, 1662.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 109/210...
#
# 0: 1024x1024 1 0, 1 1, 1670.3ms
# Speed: 6.1ms preprocess, 1670.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1661.9ms
# Speed: 5.6ms preprocess, 1661.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 110/210...
#
# 0: 1024x1024 1 0, 1 1, 1673.9ms
# Speed: 5.9ms preprocess, 1673.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1659.8ms
# Speed: 5.8ms preprocess, 1659.8ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 111/210...
#
# 0: 1024x1024 1 0, 1663.0ms
# Speed: 5.7ms preprocess, 1663.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1659.6ms
# Speed: 6.0ms preprocess, 1659.6ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 112/210...
#
# 0: 1024x1024 1 0, 1 1, 1666.2ms
# Speed: 5.7ms preprocess, 1666.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1662.8ms
# Speed: 5.8ms preprocess, 1662.8ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 113/210...
#
# 0: 1024x1024 1 0, 1 1, 1669.0ms
# Speed: 5.6ms preprocess, 1669.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1664.5ms
# Speed: 6.1ms preprocess, 1664.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 114/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1673.3ms
# Speed: 5.6ms preprocess, 1673.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1679.1ms
# Speed: 5.9ms preprocess, 1679.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 115/210...
#
# 0: 1024x1024 1 0, 1 1, 1659.8ms
# Speed: 5.5ms preprocess, 1659.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1663.7ms
# Speed: 5.8ms preprocess, 1663.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 116/210...
#
# 0: 1024x1024 1 0, 1662.9ms
# Speed: 5.3ms preprocess, 1662.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1678.8ms
# Speed: 5.9ms preprocess, 1678.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 117/210...
#
# 0: 1024x1024 1 0, 1654.7ms
# Speed: 5.7ms preprocess, 1654.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1685.7ms
# Speed: 5.7ms preprocess, 1685.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 118/210...
#
# 0: 1024x1024 1 0, 1 1, 1660.7ms
# Speed: 5.7ms preprocess, 1660.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1687.6ms
# Speed: 6.0ms preprocess, 1687.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 119/210...
#
# 0: 1024x1024 1 0, 1 1, 1660.5ms
# Speed: 5.6ms preprocess, 1660.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1681.3ms
# Speed: 5.6ms preprocess, 1681.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 120/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1664.1ms
# Speed: 5.5ms preprocess, 1664.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1693.2ms
# Speed: 5.7ms preprocess, 1693.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 121/210...
#
# 0: 1024x1024 1 0, 1 1, 1667.2ms
# Speed: 5.8ms preprocess, 1667.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1682.6ms
# Speed: 5.9ms preprocess, 1682.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 122/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1666.7ms
# Speed: 5.4ms preprocess, 1666.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1687.2ms
# Speed: 6.4ms preprocess, 1687.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 123/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1663.9ms
# Speed: 5.3ms preprocess, 1663.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1681.9ms
# Speed: 5.7ms preprocess, 1681.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 124/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1662.3ms
# Speed: 5.5ms preprocess, 1662.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1679.0ms
# Speed: 6.1ms preprocess, 1679.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 125/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1655.3ms
# Speed: 5.5ms preprocess, 1655.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1674.9ms
# Speed: 6.0ms preprocess, 1674.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 126/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1663.1ms
# Speed: 5.5ms preprocess, 1663.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1682.9ms
# Speed: 5.8ms preprocess, 1682.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 127/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1661.8ms
# Speed: 5.5ms preprocess, 1661.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1679.3ms
# Speed: 5.6ms preprocess, 1679.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 128/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1657.3ms
# Speed: 5.5ms preprocess, 1657.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1679.4ms
# Speed: 6.2ms preprocess, 1679.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 129/210...
#
# 0: 1024x1024 1 0, 1 1, 1654.9ms
# Speed: 5.6ms preprocess, 1654.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1678.1ms
# Speed: 5.7ms preprocess, 1678.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 130/210...
#
# 0: 1024x1024 1 0, 1 1, 1665.1ms
# Speed: 6.1ms preprocess, 1665.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1679.0ms
# Speed: 5.7ms preprocess, 1679.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 131/210...
#
# 0: 1024x1024 1 0, 1 1, 1660.6ms
# Speed: 5.5ms preprocess, 1660.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1672.0ms
# Speed: 6.1ms preprocess, 1672.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 132/210...
#
# 0: 1024x1024 1 0, 1661.4ms
# Speed: 5.6ms preprocess, 1661.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1672.6ms
# Speed: 5.8ms preprocess, 1672.6ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 133/210...
#
# 0: 1024x1024 1 0, 1663.4ms
# Speed: 5.5ms preprocess, 1663.4ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1672.7ms
# Speed: 6.1ms preprocess, 1672.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 134/210...
#
# 0: 1024x1024 1 0, 1669.0ms
# Speed: 6.0ms preprocess, 1669.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1668.7ms
# Speed: 5.9ms preprocess, 1668.7ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 135/210...
#
# 0: 1024x1024 1 0, 1669.8ms
# Speed: 5.7ms preprocess, 1669.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1670.0ms
# Speed: 5.9ms preprocess, 1670.0ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 136/210...
#
# 0: 1024x1024 1 0, 1663.8ms
# Speed: 5.7ms preprocess, 1663.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1663.1ms
# Speed: 5.7ms preprocess, 1663.1ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 137/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1669.7ms
# Speed: 5.9ms preprocess, 1669.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1658.8ms
# Speed: 6.0ms preprocess, 1658.8ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 138/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1675.6ms
# Speed: 6.0ms preprocess, 1675.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1660.0ms
# Speed: 5.6ms preprocess, 1660.0ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 139/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1678.0ms
# Speed: 5.7ms preprocess, 1678.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1658.1ms
# Speed: 5.8ms preprocess, 1658.1ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 140/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1679.2ms
# Speed: 5.9ms preprocess, 1679.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1653.2ms
# Speed: 6.5ms preprocess, 1653.2ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 141/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1682.7ms
# Speed: 5.9ms preprocess, 1682.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1668.3ms
# Speed: 5.8ms preprocess, 1668.3ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 142/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1682.7ms
# Speed: 5.8ms preprocess, 1682.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1659.7ms
# Speed: 5.9ms preprocess, 1659.7ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 143/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1679.6ms
# Speed: 5.9ms preprocess, 1679.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1662.2ms
# Speed: 5.9ms preprocess, 1662.2ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 144/210...
#
# 0: 1024x1024 1 0, 1 1, 1678.6ms
# Speed: 5.7ms preprocess, 1678.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1656.8ms
# Speed: 5.7ms preprocess, 1656.8ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 145/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1678.9ms
# Speed: 5.8ms preprocess, 1678.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1660.9ms
# Speed: 6.2ms preprocess, 1660.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 146/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1679.2ms
# Speed: 5.8ms preprocess, 1679.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1657.5ms
# Speed: 5.7ms preprocess, 1657.5ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 147/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1677.7ms
# Speed: 6.7ms preprocess, 1677.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1664.2ms
# Speed: 6.2ms preprocess, 1664.2ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 148/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1672.8ms
# Speed: 5.6ms preprocess, 1672.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1669.6ms
# Speed: 5.6ms preprocess, 1669.6ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 149/210...
#
# 0: 1024x1024 1 0, 1 1, 1676.2ms
# Speed: 5.7ms preprocess, 1676.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1658.1ms
# Speed: 5.9ms preprocess, 1658.1ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 150/210...
#
# 0: 1024x1024 1 0, 1678.7ms
# Speed: 8.4ms preprocess, 1678.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1667.7ms
# Speed: 5.8ms preprocess, 1667.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 151/210...
#
# 0: 1024x1024 (no detections), 1650.9ms
# Speed: 5.5ms preprocess, 1650.9ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1681.3ms
# Speed: 5.9ms preprocess, 1681.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 152/210...
#
# 0: 1024x1024 1 0, 1659.4ms
# Speed: 5.7ms preprocess, 1659.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1684.0ms
# Speed: 5.8ms preprocess, 1684.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 153/210...
#
# 0: 1024x1024 1 0, 1660.5ms
# Speed: 5.7ms preprocess, 1660.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1688.6ms
# Speed: 6.5ms preprocess, 1688.6ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 154/210...
#
# 0: 1024x1024 (no detections), 1654.4ms
# Speed: 5.6ms preprocess, 1654.4ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1697.4ms
# Speed: 6.6ms preprocess, 1697.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 155/210...
#
# 0: 1024x1024 1 0, 1664.3ms
# Speed: 5.9ms preprocess, 1664.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1691.8ms
# Speed: 6.2ms preprocess, 1691.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 156/210...
#
# 0: 1024x1024 1 0, 1 1, 1669.2ms
# Speed: 5.4ms preprocess, 1669.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1693.0ms
# Speed: 6.2ms preprocess, 1693.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 157/210...
#
# 0: 1024x1024 1 0, 1 1, 1659.0ms
# Speed: 5.5ms preprocess, 1659.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1671.6ms
# Speed: 5.8ms preprocess, 1671.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 158/210...
#
# 0: 1024x1024 1 0, 1655.4ms
# Speed: 5.3ms preprocess, 1655.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1675.1ms
# Speed: 5.8ms preprocess, 1675.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 159/210...
#
# 0: 1024x1024 1 0, 1664.1ms
# Speed: 5.6ms preprocess, 1664.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1674.5ms
# Speed: 6.0ms preprocess, 1674.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 160/210...
#
# 0: 1024x1024 1 0, 1657.4ms
# Speed: 5.5ms preprocess, 1657.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1663.9ms
# Speed: 6.1ms preprocess, 1663.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 161/210...
#
# 0: 1024x1024 1 0, 1654.7ms
# Speed: 5.4ms preprocess, 1654.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1666.3ms
# Speed: 5.7ms preprocess, 1666.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 162/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1670.8ms
# Speed: 6.0ms preprocess, 1670.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 163/210...
#
# 0: 1024x1024 1 0, 1653.4ms
# Speed: 5.6ms preprocess, 1653.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1665.8ms
# Speed: 6.1ms preprocess, 1665.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 164/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1671.0ms
# Speed: 6.1ms preprocess, 1671.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 165/210...
#
# 0: 1024x1024 1 0, 1657.7ms
# Speed: 6.5ms preprocess, 1657.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1666.8ms
# Speed: 5.8ms preprocess, 1666.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 166/210...
#
# 0: 1024x1024 1 0, 1667.6ms
# Speed: 5.8ms preprocess, 1667.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 167/210...
#
# 0: 1024x1024 1 0, 1 1, 1664.7ms
# Speed: 5.6ms preprocess, 1664.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1665.5ms
# Speed: 6.0ms preprocess, 1665.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 168/210...
#
# 0: 1024x1024 1 0, 1663.3ms
# Speed: 5.8ms preprocess, 1663.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 169/210...
#
# 0: 1024x1024 1 0, 1 1, 1655.8ms
# Speed: 5.4ms preprocess, 1655.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1668.1ms
# Speed: 5.8ms preprocess, 1668.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 170/210...
#
# 0: 1024x1024 1 0, 1 1, 1671.1ms
# Speed: 6.0ms preprocess, 1671.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 171/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1665.8ms
# Speed: 6.6ms preprocess, 1665.8ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 172/210...
#
# 0: 1024x1024 1 0, 1672.5ms
# Speed: 6.3ms preprocess, 1672.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 173/210...
#
# 0: 1024x1024 1 0, 1667.4ms
# Speed: 5.9ms preprocess, 1667.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 174/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1669.5ms
# Speed: 6.2ms preprocess, 1669.5ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 175/210...
#
# 0: 1024x1024 1 0, 1675.2ms
# Speed: 6.3ms preprocess, 1675.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 176/210...
#
# 0: 1024x1024 1 0, 1 1, 1694.9ms
# Speed: 6.1ms preprocess, 1694.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 177/210...
#
# 0: 1024x1024 1 0, 1 1, 1703.3ms
# Speed: 6.0ms preprocess, 1703.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 178/210...
#
# 0: 1024x1024 1 0, 1 1, 1696.7ms
# Speed: 6.1ms preprocess, 1696.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 179/210...
#
# 0: 1024x1024 1 0, 1 1, 1708.9ms
# Speed: 6.1ms preprocess, 1708.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 180/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1692.5ms
# Speed: 5.9ms preprocess, 1692.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 181/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1677.9ms
# Speed: 6.3ms preprocess, 1677.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 182/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1706.2ms
# Speed: 6.4ms preprocess, 1706.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 183/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1695.3ms
# Speed: 6.3ms preprocess, 1695.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 184/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1699.5ms
# Speed: 6.3ms preprocess, 1699.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 185/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1697.4ms
# Speed: 6.3ms preprocess, 1697.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 186/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1701.4ms
# Speed: 7.0ms preprocess, 1701.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 187/210...
#
# 0: 1024x1024 1 0, 1691.6ms
# Speed: 6.2ms preprocess, 1691.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 188/210...
#
# 0: 1024x1024 1 0, 1696.5ms
# Speed: 6.2ms preprocess, 1696.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 189/210...
#
# 0: 1024x1024 1 0, 1 1, 1689.4ms
# Speed: 6.0ms preprocess, 1689.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 190/210...
#
# 0: 1024x1024 (no detections), 1677.2ms
# Speed: 6.1ms preprocess, 1677.2ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 191/210...
#
# 0: 1024x1024 1 0, 1 1, 1678.9ms
# Speed: 5.4ms preprocess, 1678.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1670.1ms
# Speed: 6.2ms preprocess, 1670.1ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 192/210...
#
# 0: 1024x1024 1 0, 1677.2ms
# Speed: 5.9ms preprocess, 1677.2ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1657.7ms
# Speed: 6.8ms preprocess, 1657.7ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 193/210...
#
# 0: 1024x1024 (no detections), 1652.6ms
# Speed: 6.2ms preprocess, 1652.6ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1676.8ms
# Speed: 5.8ms preprocess, 1676.8ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 194/210...
#
# 0: 1024x1024 1 0, 1657.9ms
# Speed: 5.9ms preprocess, 1657.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 (no detections), 1676.2ms
# Speed: 5.8ms preprocess, 1676.2ms inference, 0.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 195/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1668.6ms
# Speed: 5.7ms preprocess, 1668.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1683.2ms
# Speed: 5.8ms preprocess, 1683.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 196/210...
#
# 0: 1024x1024 1 0, 1 1, 1669.0ms
# Speed: 5.6ms preprocess, 1669.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1686.6ms
# Speed: 6.3ms preprocess, 1686.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 197/210...
#
# 0: 1024x1024 1 0, 1 1, 1676.4ms
# Speed: 5.7ms preprocess, 1676.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1684.9ms
# Speed: 5.9ms preprocess, 1684.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 198/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1681.9ms
# Speed: 6.0ms preprocess, 1681.9ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1674.2ms
# Speed: 6.4ms preprocess, 1674.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 199/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1683.5ms
# Speed: 6.0ms preprocess, 1683.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1687.4ms
# Speed: 5.8ms preprocess, 1687.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 200/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1680.4ms
# Speed: 5.6ms preprocess, 1680.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1683.9ms
# Speed: 6.0ms preprocess, 1683.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 201/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1680.7ms
# Speed: 5.8ms preprocess, 1680.7ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1685.1ms
# Speed: 6.0ms preprocess, 1685.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 202/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1686.6ms
# Speed: 5.5ms preprocess, 1686.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1682.5ms
# Speed: 6.0ms preprocess, 1682.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 203/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1679.8ms
# Speed: 5.6ms preprocess, 1679.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1684.6ms
# Speed: 5.8ms preprocess, 1684.6ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 204/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1681.4ms
# Speed: 5.6ms preprocess, 1681.4ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1686.0ms
# Speed: 6.6ms preprocess, 1686.0ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 205/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1680.8ms
# Speed: 5.6ms preprocess, 1680.8ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1682.3ms
# Speed: 6.7ms preprocess, 1682.3ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 206/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1679.4ms
# Speed: 5.7ms preprocess, 1679.4ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1681.3ms
# Speed: 6.0ms preprocess, 1681.3ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 207/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1678.1ms
# Speed: 5.8ms preprocess, 1678.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1683.6ms
# Speed: 6.2ms preprocess, 1683.6ms inference, 0.6ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 208/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1683.5ms
# Speed: 6.3ms preprocess, 1683.5ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1679.7ms
# Speed: 6.5ms preprocess, 1679.7ms inference, 0.4ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 209/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1683.2ms
# Speed: 5.7ms preprocess, 1683.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1679.9ms
# Speed: 6.5ms preprocess, 1679.9ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing frame 210/210...
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1688.1ms
# Speed: 5.8ms preprocess, 1688.1ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
#
# 0: 1024x1024 1 0, 1 1, 1 2, 1 3, 1 4, 1 5, 1681.2ms
# Speed: 6.2ms preprocess, 1681.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1024, 1024)
# Processing complete! Output video saved at: /content/drive/MyDrive/VLM/output_video.mp4
